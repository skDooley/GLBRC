# %% [markdown]
# <h2><a id="meta">GLBRC Metadata</a></h2>
# <p style="color:darkred">Showing 25/136 samples</p>

# %% [markdown]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nucleic_acid_name</th>
#       <th>treatment</th>
#       <th>plot_name</th>
#       <th>rep</th>
#       <th>sampling_date</th>
#       <th>Sampling Time</th>
#       <th>type</th>
#       <th>Date</th>
#     </tr>
#     <tr>
#       <th>reads_file_name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11425.5.206700.GCCTTGT-AACAAGG.fastq.gz</th>
#       <td>G5R1_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R1_NF</td>
#       <td>1</td>
#       <td>5/9/16</td>
#       <td>12:00</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.CTGACAC-TGTGTCA.fastq.gz</th>
#       <td>G5R2_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R2_NF</td>
#       <td>2</td>
#       <td>5/9/16</td>
#       <td>14:43</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.CCAGTGT-AACACTG.fastq.gz</th>
#       <td>G5R3_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R3_NF</td>
#       <td>3</td>
#       <td>5/9/16</td>
#       <td>15:26</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.TGTACAC-GGTGTAC.fastq.gz</th>
#       <td>G5R4_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R4_NF</td>
#       <td>4</td>
#       <td>5/9/16</td>
#       <td>13:56</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.GTTCGGT-AACCGAA.fastq.gz</th>
#       <td>G6R1_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R1_NF</td>
#       <td>1</td>
#       <td>5/9/16</td>
#       <td>16:04</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.6.206725.ACAGCAA-GTTGCTG.fastq.gz</th>
#       <td>G6R2_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R2_NF</td>
#       <td>2</td>
#       <td>5/9/16</td>
#       <td>13:06</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.CGTAGGT-AACCTAC.fastq.gz</th>
#       <td>G6R3_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R3_NF</td>
#       <td>3</td>
#       <td>5/9/16</td>
#       <td>15:03</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.TCATCAC-GGTGATG.fastq.gz</th>
#       <td>G6R4_NF_09MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R4_NF</td>
#       <td>4</td>
#       <td>5/9/16</td>
#       <td>15:46</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.GAGCTCA-TTGAGCT.fastq.gz</th>
#       <td>G5R1_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G5R1_MAIN</td>
#       <td>1</td>
#       <td>5/9/16</td>
#       <td>12:00</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.ATAGCGG-ACCGCTA.fastq.gz</th>
#       <td>G5R2_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G5R2_MAIN</td>
#       <td>2</td>
#       <td>5/9/16</td>
#       <td>14:43</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.4.206675.CGGTTGT-AACAACC.fastq.gz</th>
#       <td>G5R3_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G5R3_MAIN</td>
#       <td>3</td>
#       <td>5/9/16</td>
#       <td>15:26</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.4.206675.TACCAAC-GGTTGGT.fastq.gz</th>
#       <td>G5R4_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G5R4_MAIN</td>
#       <td>4</td>
#       <td>5/9/16</td>
#       <td>13:56</td>
#       <td>G5</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.TCGCTGT-AACAGCG.fastq.gz</th>
#       <td>G6R1_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G6R1_MAIN</td>
#       <td>1</td>
#       <td>5/9/16</td>
#       <td>13:06</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.AGCTAAC-GGTTAGC.fastq.gz</th>
#       <td>G6R2_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G6R2_MAIN</td>
#       <td>2</td>
#       <td>5/9/16</td>
#       <td>15:03</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.GGACTGT-AACAGTC.fastq.gz</th>
#       <td>G6R3_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G6R3_MAIN</td>
#       <td>3</td>
#       <td>5/9/16</td>
#       <td>15:46</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11425.6.206725.ACGGAAC-TGTTCCG.fastq.gz</th>
#       <td>G6R4_MAIN_09MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G6R4_MAIN</td>
#       <td>4</td>
#       <td>5/9/16</td>
#       <td>13:56</td>
#       <td>G6</td>
#       <td>2016-05-09</td>
#     </tr>
#     <tr>
#       <th>11815.1.220223.AGTCA.fastq.gz</th>
#       <td>G5R1_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R1_NF</td>
#       <td>1</td>
#       <td>5/31/16</td>
#       <td>11:42</td>
#       <td>G5</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11814.1.220215.TAGCT.fastq.gz</th>
#       <td>G5R2_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R2_NF</td>
#       <td>2</td>
#       <td>5/31/16</td>
#       <td>13:26</td>
#       <td>G5</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.CCTCAGT-AACTGAG.fastq.gz</th>
#       <td>G5R3_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R3_NF</td>
#       <td>3</td>
#       <td>5/31/16</td>
#       <td>14:13</td>
#       <td>G5</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.TTCGTAC-GGTACGA.fastq.gz</th>
#       <td>G5R4_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G5R4_NF</td>
#       <td>4</td>
#       <td>5/31/16</td>
#       <td>12:37</td>
#       <td>G5</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.GTGAGCT-AAGCTCA.fastq.gz</th>
#       <td>G6R1_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R1_NF</td>
#       <td>1</td>
#       <td>5/31/16</td>
#       <td>12:08</td>
#       <td>G6</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.CAATCGA-GTCGATT.fastq.gz</th>
#       <td>G6R2_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R2_NF</td>
#       <td>2</td>
#       <td>5/31/16</td>
#       <td>13:47</td>
#       <td>G6</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.CCTTCCT-AAGGAAG.fastq.gz</th>
#       <td>G6R3_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R3_NF</td>
#       <td>3</td>
#       <td>5/31/16</td>
#       <td>14:40</td>
#       <td>G6</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.5.206700.TGACTGA-GTCAGTC.fastq.gz</th>
#       <td>G6R4_NF_31MAY2016_LD1</td>
#       <td>nitrogen free</td>
#       <td>G6R4_NF</td>
#       <td>4</td>
#       <td>5/31/16</td>
#       <td>12:55</td>
#       <td>G6</td>
#       <td>2016-05-31</td>
#     </tr>
#     <tr>
#       <th>11425.3.206650.TGTGCGT-AACGCAC.fastq.gz</th>
#       <td>G5R1_MAIN_31MAY2016_LD1</td>
#       <td>standard fertilization</td>
#       <td>G5R1_MAIN</td>
#       <td>1</td>
#       <td>5/31/16</td>
#       <td>11:42</td>
#       <td>G5</td>
#       <td>2016-05-31</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h2><a id="meta">Assembly Stats Overview</a></h2>
#
# <ul>
#     <li>Number of contigs: 12,301,483</li>
#     <li>8,351,528,570 bp</li>
#     <li>Longest contig: 198,213 bp</li>
#     <li>Average contig length: 679 bp</li>
# </ul>

# %% [markdown]
# <h2><a id="also">Alignment Stats Overview</a></h2>

# %% [markdown]
# <p style="color:darkred">Alignment Stats by Percentage</p>
#
# ![](PEAlign.png)

# %% [markdown]
# <p style="color:darkred">Alignment Stats by read count</p>
#
# ![](PEAlign_readCount.png)

# %% [markdown]
# <p style="color:darkred">After grouping alignment counts by sampling date, crop, and treatment we looked at the presence/absence of each contig across all samples</p>

# %% [markdown]
# ![abd](Abundance_combined.png)

# %% [markdown]
# <h3><a id="OXA">Occupancy X Abundance</a></h3>
#
# ![](OccupencyAbundance.png)

# %% [markdown]
# <h2><a id="nmds">NMDS</a></h2>
# <h5 style="color:darkgreen">NMDS with all combined samples</h5>
# <p>As you can see from the graph below, generally miscanthus and switch grass combined samples tend to be the most similar. As sampling time increases the bacterial microbiomes grow more similar. There is no detectable fertilization effect in the phyllosphere.</p>
#
# ![](AllCombinedNMDS.png)

# %% [markdown]
# <h5 style="color:darkgreen">NMDS with only Switchgrass samples</h5>
# <p>No seperation pattern between fertilized and unfertilzed Switchgrass</p>
#
# ![](SwitchGrass_NMDS.png)

# %% [markdown]
# <h5 style="color:darkgreen">NMDS with only Miscanthus samples</h5>
# <p>No seperation pattern between fertilized and unfertilzed Miscanthus</p>
#
# ![](Miscanthus_NMDS.png)

# %% [markdown]
# <h1>Next Steps</h1>
# <ol>
#     <li>Complete functional annotation of contigs</li>
#         <ul>
#             <li>Status: In Progress</li>
#             <li>ETA: 3/18/19</li>
#         </ul>
#     <li>Determine major core microbiome players</li>
#         <ul>
#             <li>Status: Dependant</li>
#             <li>ETA: 3/18/19</li>
#         </ul>
#     <li>GLBIO 2019 Poster?</li>
# </ol>
#
# ![](glBio2019.png)
#
# <br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br><br></br>
